# %% [markdown]
# ## how to measure gene expression

# %% [markdown]
# for measuring  gene expression we will use two techniques
# 1.Microarray
# 2.RNA seq analysis

# %% [markdown]
# ## Microaarray analysis

# %% [markdown]
# in this we will use probes and that have diff flourscent and attach with the Mrna or reverse dna hybrid and then the plate are washed. In this step the unhybrid or those which are not attach with the sample are removed and only left those which are attache with the micro rna will persist so we will get at the end flourescent plates which contains the mciro rna with diff probes which are combined with it.On the base of flourscent we are able to analyse that which gene are expressed in one sample or both sample or differnetialy expressed genes.This process is called microarys analysi

# %% [markdown]
# ## RNA Seq Analysis

# %% [markdown]
# in this we will use micro rna or cdna for rach against the refence genome
# in this we have two elements
# one is reference genome
# other is the micro rna
# on the bse of reach against the refernce genome we are able to tell that which genome is present in the sample or not

# %% [markdown]
# ## How to fetch the RNa seq data

# %% [markdown]
# we can fetch RNa seq data from ncbi.When we enter in the NCBI we will see diff type of data which are availble in the NCBI
# whcih are shown in the image below
# ![alt text](NCBIss.png)

# %% [markdown]
# After reaching in the ncbi u are able to acces an type of data lets supose we want to acces the GEO data sets from the ncbi for this we will select the geo data set in the top and then enter in to the GEO data types ,here we will get GEO data types and now its on us that how we will acces the data
# there are main two types to access the data
# first is accessing directly by entering the name for data sets and in this way we will get the data sets
# second is accessing the data by using the accession number of the data sets because each data have diff types of accesion number
# below the pic i showed both that we can enter the GEO accessin nm or we can written the name of any type of data we need u can see below the image which i put below
# ![GEOss.png](attachment:GEOss.png)

# %% [markdown]
# we will able to download the data in the form of tar so we are able to unzip the files for unzip the files we are able to done it by using diff command on the systm
# if we have window or linux systme we can use cmd or terminal to unzip the files here is the code for unzip are given below.

# %% [markdown]
# #Windows: Use tar -xf, Expand-Archive, or 7-Zip.
# #Linux: Use unzip, tar -xvzf, or unrar.
